# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Ask the user to input the image path
image_path = input("Enter the path to the image: ")

# Read the image
image = cv2.imread(image_path)

if image is not None:
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Display the grayscale image using matplotlib
    plt.imshow(gray, cmap='gray')
    plt.axis('off')  # Turn off axis labels
    plt.show()
else:
    print("Image not found or could not be loaded. Please check the path.")
# Out:
# Enter the path to the image: /content/freezer_image (1).jpg

# %%
blur = cv2.GaussianBlur(gray, (11, 11), 0)
plt.imshow(blur, cmap='gray')

# %%
canny = cv2.Canny(blur, 30, 150, 3)
plt.imshow(canny, cmap='gray')

# %%
dilated = cv2.dilate(canny, (1, 1), iterations=0)
plt.imshow(dilated, cmap='gray')

# %%
(cnt, hierarchy) = cv2.findContours(
	dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)

plt.imshow(rgb)

# %%
print(" items in the freezer : ", len(cnt))
# Out:
#  items in the freezer :  1134
